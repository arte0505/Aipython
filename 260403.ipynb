# %%
import random
answer=(random.randint(1,100))
answer
# Out:
# 65

# %%
answer
# Out:
# 65

# %%
user=int(input('추측값을 입력하시오'))
# Out:
# 추측값을 입력하시오60

# %%
n = 0
while user != answer:
  n = n + 1
  if user > answer:
    print('더 작은 수를 입력하시오')
  else:
    print('더 큰 수를 입력하시오')
  user=int(input('추측값을 입력하시오'))
print(f"{n}번 만에 맞췄습니다")
# Out:
# 더 큰 수를 입력하시오
# 추측값을 입력하시오62
# 더 큰 수를 입력하시오
# 추측값을 입력하시오64
# 더 큰 수를 입력하시오
# 추측값을 입력하시오65
# 3번 만에 맞췄습니다

# %%
n=int(input())
for i in range(1,n+1):
  if n%i==0:
    print(i)
# Out:
# 132
# 1
# 2
# 3
# 4
# 6
# 11
# 12
# 22
# 33
# 44
# 66
# 132
